# %%
x = 'Hello world*******'
print(x)
# Out:
# Hello world*******

# %%
print('hello world!')
# Out:
# hello world!

# %%
y = 'HELLO WORLD!'
print(y)
# Out:
# HELLO WORLD!

# %%
pritn('HelloWorld !')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-eeca55ac6334> in <cell line: 1>()
# ----> 1 pritn('HelloWorld !')
#
# NameError: name 'pritn' is not defined

# %%
print('HelloWorld !')
# Out:
# HelloWorld !

# %%
a = 1
b = 12
y = a+100*b
print(y)
# Out:
# 1201
